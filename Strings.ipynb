# %% [markdown]
# <a href="https://colab.research.google.com/github/manthribharadwaj12/CRT-221710313031/blob/master/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #STRINGS

# %% [markdown]
# ```
# #include<stdio.h>
# int main()
# { char x[100];
# int i;
# scanf("%s",x);//gets not valid
# //scanf("%[^\n]s",x);
# printf("%s",x);
# return 0;
# }
#
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i,len=0;
# scanf("%[^\n]s",x);
# len=strlen(x);// manually with loop
# printf("%d",len);
# return 0;
# }
# ```
# ---

# %% [markdown]
#
# >input-   Output
#
# AppLICaTion   -- U : 5 L : 6
#
# ---
#
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i,len=0,cap=0,low=0,l;
# scanf("%[^\n]s",x);
# len=strlen(x);
# for(i=0;i<len;i++)
# {
# if(65<=x[i] && x[i]<=90)
# cap++;
# if(97<=x[i] && x[i]<=122)
# low++;
# }
# printf("-- U: %d L: %d ",cap,low);
# return 0;
# }
# ```
# ---

# %% [markdown]
# input-output
#
# Appli18cati89on   -- 16
#
# ---
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i,len=0,sum=0,l;
# scanf("%[^\n]s",x);
# len=strlen(x);
# for(i=0;i<len;i++)
# { l=x[i];
# if(48<=x[i] && x[i]<=57 && x[i]%2==0)
# sum=sum+l-48;
# }
# printf("%d ",sum);
# return 0;
# }
# ```
#
# ---

# %% [markdown]
# input -- outPut
#
# orange -- puboif
#
# ---
#
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i,len=0,sum=0,l;
# scanf("%[^\n]s",x);
# len=strlen(x);
# for(i=0;i<len;i++)
# {
# if(x[i]=='a'||x[i]=='e'||x[i]=='i'||x[i]=='o'||x[i]=='u')
#  x[i]=x[i]+1;
# else if(x[i]>='b' && x[i]<='d')
# x[i]='e';
# else if(x[i]>='f' && x[i]<='h')
# x[i]='i';
# else if(x[i]>='j' && x[i]<='n')
# x[i]='o';
# else if(x[i]>='p' && x[i]<='t')
# x[i]='u';
# else if(x[i]>='v' && x[i]<='z')
# x[i]='a';
# }
# printf("%s",x);
# return 0;
# }
# ```
#
# ---

# %% [markdown]
# input -- output
#
# App teSt working -- TEST
#
# ---
#
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i=0,len=0,l=0,count=0,n,a[10];
# scanf("%[^\n]s",x);
# len=strlen(x);
# for(i=0;i<len;i++)
# {if(x[i]==32)
#  count++;
#  if(count==1)
#  {if(x[i]<=122 && x[i]>=90)
# 	{	printf("%c",x[i]-32);}
#  if(x[i]<=90 && x[i]>=65)
#   printf("%c",x[i]);
#  }
#  if(count==2)
#  break;
#  }
# return 0;
# }
# #scanf n and put it in place 2 and accordingly change
# ```
# ---

# %% [markdown]
# input -- output
#
# abc xyz -- axbycz
#
# abcd xy -- axbycd
#
# ab xyza -- axbyza
#
# ---
#
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char s1[50],s2[50],s3[50];
# int len1=0,len2=0,i,j;
# scanf("%s %s",s1,s2);
# len1=strlen(s1);
# len2=strlen(s2);
#   if(len1==len2)
#    for(i=0;i<len1;i++)
#    printf("%c%c",s1[i],s2[j]);
#    else if(len1<len2)
#    {for(i=0;i<len1;i++)
#    printf("%c%c",s1[i],s2[i]);
# 	for(i=len1;i<len2;i++)
#    printf("%c",s2[i]);
#    }
#    else if(len1>len2)
#    {for(i=0;i<len2;i++)
#    printf("%c%c",s1[i],s2[i]);
#    for(i=len2;i<len1;i++)
#    printf("%c",s1[i]);
#    }
# return 0;
# }
# ```
# ---

# %% [markdown]
# mango eat --
#
#              me
#
#              aa
#
#              nt
#
#              g*
#
#              o*
#
#   eat mango --
#
#              em
#
#              aa
#
#              tn
#
#              *g
#
#              *o
#
# ---
#
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char s1[50],s2[50],s3[50];
# int len1=0,len2=0,i,j;
# scanf("%s %s",s1,s2);
# len1=strlen(s1);
# len2=strlen(s2);
#   if(len1==len2)
#    for(i=0;i<len1;i++)
#    printf("%c%c\n",s1[i],s2[j]);
#    else if(len1<len2)
#    {for(i=0;i<len1;i++)
#    printf("%c%c\n",s1[i],s2[i]);
# 	for(i=len1;i<len2;i++)
#    printf("*%c\n",s2[i]);
#    }
#    else if(len1>len2)
#    {for(i=0;i<len2;i++)
#    printf("%c%c\n",s1[i],s2[i]);
#    for(i=len2;i<len1;i++)
#    printf("%c*\n",s1[i]);
#    }
# return 0;
# }
# ```
#
# ---

# %% [markdown]
# App Test Working Good -- APP Test WORKING Good
#
# ---
#
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i=0,len=0,l=0,count=0,n,a[10];
# scanf("%[^\n]s",x);
# len=strlen(x);
# for(i=0;i<len;i++)
# {if(x[i]==32)
#  {
#  count++;
#  printf("%c",x[i]);}
#  if(count%2!=1)
#  {if(x[i]<=122 && x[i]>=90)
# 	{	printf("%c",x[i]-32);}
#  if(x[i]<=90 && x[i]>=65)
#   printf("%c",x[i]);
#  }
#  else
#  printf("%c",x[i]);
#  }
# return 0;
# }
# ```
# ---

# %% [markdown]
# hi hwllo good morning -- 7
#
# ---
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i=0,len=0,l=0,count=0,n1=0,n2=0;
# scanf("%[^\n]s",x);
# len=strlen(x);
# for(i=0;i<len;i++)
# {if(x[i]==32)
#  {
#  count++;
#  if(n1>n2)
#  {n2=n1;}
#  n1=0;
#  }
# else
# n1++;
# }
# if(n1>n2)
#  {n2=n1;}
# printf("%d",n2);
# return 0;
# }
# ```
#
# ---

# %% [markdown]
# hi good morning    --  morning
#
# ---
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i=0,len=0,count=0,n1=0,n2=0,l=0,k=0;
# scanf("%[^\n]s",x);
# len=strlen(x);
# for(i=0;i<len;i++)
# {if(x[i]==32)
#  {
#  count++;
#  if(n1>n2)
#  {n2=n1;
#  l=i-n2;
#  k=i;}
#  n1=0;
#  }
# else
# {
# n1++;
# }
# }
#  if(n1>n2)
#  {n2=n1;
#  l=i-n2;
#  k=i;}
# for(i=l;i<=k;i++)
# printf("%c",x[i]);
# return 0;
# }
# ```
#
# ---

# %% [markdown]
# whitegreenblack 3 -- white green black
#
# pencilrubber 5 -- -1
#
# ---
#
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i=0,n,l,m=1,k=0;
# scanf("%s",x);
# scanf("%d",&n);
# l=strlen(x);
# k=l/n;
# if(l%n==0)
# { for(i=0;i<l;i++)
#   { if(i==(k*m) && m<l) //if(i%k==0 && i!=0) without m
#   	{
# 	  printf(" ");
#     m++;
#     printf("%c",x[i]);
# 	}
#   	else
#   	printf("%c",x[i]);
#   }
# }
# else
# printf("-1");
# return 0;
# }
# ```

# %% [markdown]
# ABCD AABBCC ABCDABCD
#
#
#                        !@@!!!@@@@
#                        !@!!@@!!!@@@
#                        !@@!!!@@@@!@@!!!@@@@
#
# ---
#
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100],ch='!';
# int i=0,n,l,k,m=1,j=0;
# scanf("%[^\n]s",x);
# l=strlen(x);
# for(i=0;i<l;i++)
# {if(x[i]==32)
#  {
#  printf("\n");
#  ch='!'}
#  else
#   { k=x[i]-64;
#   for(j=0;j<k;j++){
#   	printf("%c",ch);
#   }
#   if(ch=='!')
#   ch='@';
#  else
#   ch='!';
#  }
#  }
# return 0;
# }
# ```
#
# ---

# %% [markdown]
# ABCD AABBCC ABCDABCD
#
# [output](https://photos.app.goo.gl/fyCdFNuwzMykLzzc8)
#
# ---
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100],ch='!';
# int i=0,n,l,k,m=1,j=0;
# scanf("%[^\n]s",x);
# l=strlen(x);
# for(i=0;i<l;i++)
# {if(x[i]==32)
#  {
#  printf("\n");
#  ch='!';}
#  else
#  { k=x[i]-64;
#   for(j=0;j<k;j++){
#   	printf("%c",ch);
#   }
#   if(ch=='!')
#   ch='@';
#   else if(ch=='@')
#   ch='$';
#   else
#   ch='!';
#  }
#  }
# return 0;
# }
# ```
#
#
#
#
#
# ---

# %% [markdown]
# dhyanahita 4 -- dhyanaatih
#
# ---
#
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i=0,n,l,j;
# scanf("%s%d",x,&n);
# l=strlen(x);
# for(i=0;i<l-n;i++)
# printf("%c",x[i]);
# for(j=l-1;j>=l-n;j--)
# printf("%c",x[j]);
# return 0;
# }
# ```
# ---

# %% [markdown]
# dhyanahita 4 -- ayhdnaatih
#
# ---
#
#
# ```
# #include<stdio.h>
# #include<string.h>
# int main()
# { char x[100];
# int i=0,n,l,j;
# scanf("%s%d",x,&n);
# l=strlen(x);
# for(i=n-1;i>=0;i--)
# printf("%c",x[i]);
# for(i=n;i<l-n;i++)
# printf("%c",x[i]);
# for(j=l-1;j>=l-n;j--)
# printf("%c",x[j]);
# return 0;
# }
# ```
#
# ---
